# %% [markdown]
# # Sample Python notebook
#
# This notebook was created to allow collaboration via MyBinder

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
trace = list(map(lambda x: int(np.random.randn() * 1000), range(100)))

plt.plot(trace)
plt.xlabel("Time")
plt.ylabel("Random")
# Out:
# Text(0, 0.5, 'Random')
